# %%
import anndata
import scanpy as sc
from sklearn import metrics
import matplotlib as mpl
from matplotlib import pyplot as plt
import numpy as np
import plotly.express as px

adata = anndata.read_h5ad(filename='Tutorial/all_adatas/151670_adata.h5ad')

# %%
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 3484 × 33538
#     obs: 'in_tissue', 'array_row', 'array_col', 'imagecol', 'imagerow', 'slices_path', 'Ground_Truth', 'mclust'
#     var: 'gene_ids', 'feature_types', 'genome', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'mean', 'std'
#     uns: 'ARI', 'Ground_Truth_colors', 'hvg', 'log1p', 'mclust_colors', 'neighbors', 'spatial'
#     obsm: 'adj', 'combined_feat', 'distance_matrix', 'emb', 'emb_pca', 'feat_a', 'graph_neigh', 'image_feat', 'label_CSL', 'spatial'
#     obsp: 'connectivities', 'distances'

# %%
sc.pl.highest_expr_genes(adata, n_top=20)

# %%
cell_index = 0
gene_expression = adata.X[cell_index]
expressed_gene_indices = gene_expression.nonzero()[1]
expressed_genes = adata.var_names[expressed_gene_indices]
print(expressed_genes)
# Out:
# Index(['TNFRSF4', 'VWA1', 'GNB1', 'GABRD', 'PRKCZ', 'PEX10', 'FAM213B',
#        'ARHGEF16', 'CHD5', 'RPL22',
#        ...
#        'MT-CO2', 'MT-ATP8', 'MT-ATP6', 'MT-CO3', 'MT-ND3', 'MT-ND4L', 'MT-ND4',
#        'MT-ND5', 'MT-ND6', 'MT-CYB'],
#       dtype='object', length=2216)

# %%
with mpl.rc_context({'figure.figsize': [6, 7], 'axes.facecolor': 'black'}):
    sc.pl.spatial(adata,
                  color=[ "HES4","SDF4", "CPTP"],
                  img_key=None,
                  size=1,
                  vmin=0,
                  cmap='magma',
                  vmax='p99.0',
                  gene_symbols='SYMBOL'
                 )

# %%
gene_counts_sum = np.sum(adata.X, axis=0)
gene_with_most_counts = adata.var_names[np.argmax(gene_counts_sum)]
print("Gene with the most counts:", gene_with_most_counts)
# Out:
# Gene with the most counts: MT-ND1

# %%
sc.tl.umap(adata, n_components=2)
sc.pl.umap(adata)

# %%
sc.tl.diffmap(adata)

# %%
sc.pl.diffmap(adata, color='mclust')

# %%
sc.pl.diffmap(adata, color='Ground_Truth')

# %%
sc.tl.draw_graph(adata)
# Out:
# WARNING: Package 'fa2' is not installed, falling back to layout 'fr'.To use the faster and better ForceAtlas2 layout, install package 'fa2' (`pip install fa2`).

# %%
sc.pl.draw_graph(adata, color=['Ground_Truth', 'mclust'])

# %%
sc.pl.umap(adata, color=["HES4", "SDF4", "CPTP"])

# %%
plt.rcParams["figure.figsize"] = (4, 4)
sc.pl.umap(adata, color=["mclust"], wspace=0.4)

# %%
sc.pl.highly_variable_genes(adata)

# %%
sc.pp.pca(adata)

# %%
sc.pl.pca_variance_ratio(adata, log=True)

# %%
sc.tl.rank_genes_groups(adata, "mclust", method="t-test")

# %%
sc.pl.rank_genes_groups(adata, n_genes=10)

# %%
result = adata.uns["rank_genes_groups"]
groups = result["names"].dtype.names
top_features = {}
n_top_genes = 10
for group in groups:
    top_features[group] = result["names"][group][:n_top_genes]

for group, features in top_features.items():
    print(f"Cluster {group} top features:")
    for feature in features:
        print(feature)
    print()
# Out:
# Cluster 1 top features:
# MBP
# PLP1
# DIRAS2
# TUBA1A
# KRT17
# GPM6A
# SCGB2A2
# GFAP
# MOBP
# SLC17A7
#
# Cluster 2 top features:
# TMSB10
# SYT1
# SNAP25
# PCP4
# STMN1
# TUBA1B
# TUBB2A
# STMN2
# SYN2
# MBP
#
# Cluster 3 top features:
# CARTPT
# HOPX
# ENC1
# CUX2
# LINC00507
# CALB1
# PCDH8
# HAPLN4
# NRGN
# LAMP5
#
# Cluster 4 top features:
# GFAP
# SAA1
# CST3
# FABP4
# MT-ND5
# MALAT1
# SPARC
# S100B
# PLIN1
# CXCL14
#
# Cluster 5 top features:
# RPL24
# RPL9
# RPS24
# RPS15A
# B2M
# RPL32
# PTGDS
# RPL41
# RPL13A
# RPS26

# %%
embedding = adata.obsm['emb_pca']
mclust_labels = adata.obs["mclust"]

fig = px.scatter_3d(
    embedding,
    x=0,
    y=1,
    z=2,
    color=mclust_labels,
    title="3D Embedding with GENESPAT",
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a7fb506e-861d-40e1-a9ff-edb86aef8945" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7fb506e-861d-40e1-a9ff-edb86aef8945")) {                    Plotly.newPlot(                        "a7fb506e-861d-40e1-a9ff-edb86aef8945",                        [{"hovertemplate":"color=3\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"3","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"3","scene":"scene","showlegend":true,"x":[-5.972431659698486,-0.3925771415233612,0.6573832631111145,0.30821922421455383,-0.22759370505809784,-0.4542115032672882,-0.16304613649845123,0.3346748352050781,2.6191909313201904,3.5505008697509766,0.1604146808385849,1.7120290994644165,5.054620742797852,3.574812173843384,2.789764881134033,4.612686634063721,5.7379231452941895,1.345853567123413,-1.764411211013794,-4.774282932281494,-1.3319969177246094,-6.269333362579346,4.174361228942871,4.8922553062438965,3.2129900455474854,0.12017180770635605,9.342399597167969,-3.643845319747925,-1.7929364442825317,2.314298629760742,1.2540946006774902,1.1586631536483765,0.8373692035675049,2.6200520992279053,3.6529414653778076,1.550880789756775,3.3631718158721924,-4.676898956298828,-1.089195728302002,0.500782310962677,3.491328477859497,6.434786319732666,-3.5924642086029053,2.6087448596954346,2.2796695232391357,-3.360913038253784,0.09392592310905457,5.326277256011963,2.767561912536621,2.1904101371765137,-0.13365913927555084,2.0538980960845947,9.66309928894043,1.7003192901611328,-6.585470676422119,3.2611122131347656,0.6174749732017517,3.056872606277466,3.804717540740967,-6.65609073638916,-4.062807559967041,-1.972111701965332,5.912363052368164,-3.937025308609009,1.3623236417770386,-1.9688020944595337,0.4560748040676117,-0.08748205751180649,4.140536785125732,5.3016743659973145,2.8504831790924072,7.409327507019043,9.224846839904785,3.3264925479888916,-3.4035110473632812,0.7847199440002441,6.752394676208496,-1.6549385786056519,0.9809648990631104,-1.1304360628128052,-5.675787925720215,2.92659068107605,4.952114105224609,2.469709873199463,1.6902213096618652,-2.7742388248443604,2.0678491592407227,-0.9252564907073975,3.917085886001587,3.939720869064331,2.089280128479004,-3.626133441925049,-2.127394199371338,4.219241142272949,2.254673957824707,-2.6176252365112305,-0.3705867528915405,6.987752914428711,-5.3101887702941895,2.545192003250122,6.838776111602783,-5.870763778686523,7.9636945724487305,0.6938964128494263,5.349637508392334,2.7921299934387207,9.308362007141113,3.5676867961883545,-4.860501289367676,-2.153225898742676,2.625962257385254,8.37458610534668,-2.406076431274414,-2.146470546722412,3.2777016162872314,3.0985546112060547,1.8015047311782837,-2.1646060943603516,-3.17846941947937,5.294589519500732,8.383218765258789,-1.7065935134887695,1.7216129302978516,-1.5134127140045166,4.259424686431885,5.658075332641602,-3.379481315612793,-0.6705891489982605,-6.551717281341553,1.8990370035171509,1.5610069036483765,-6.135962963104248,-5.463419437408447,2.253235340118408,2.8419620990753174,0.978452742099762,-0.557636022567749,6.428816795349121,-5.005305767059326,-3.3079042434692383,-7.573504447937012,-0.8433219194412231,4.325644016265869,4.47498083114624,1.749975323677063,3.699263334274292,-5.615291595458984,2.1758480072021484,-0.12552502751350403,3.0752646923065186,3.743971586227417,-0.18538373708724976,-0.2767714262008667,-0.13340306282043457,0.013906084932386875,7.786925315856934,-0.11645905673503876,6.744808673858643,2.032896041870117,-1.9772521257400513,-2.603482484817505,4.893558502197266,1.9750698804855347,1.4709059000015259,0.4164898097515106,-2.890045404434204,-2.1376750469207764,-9.667242050170898, ...

# %%
embedding = adata.obsm['emb_pca']
mclust_labels = adata.obs["Ground_Truth"]

fig = px.scatter_3d(
    embedding,
    x=0,
    y=1,
    z=2,
    color=mclust_labels,
    title="3D Embedding with Ground Truth Clustering",
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8e6ceb81-1339-4d65-bfba-66f1c1c18fd6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e6ceb81-1339-4d65-bfba-66f1c1c18fd6")) {                    Plotly.newPlot(                        "8e6ceb81-1339-4d65-bfba-66f1c1c18fd6",                        [{"hovertemplate":"color=Layer4\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Layer4","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Layer4","scene":"scene","showlegend":true,"x":[-5.972431659698486,0.6573832631111145,-3.360913038253784,-4.062807559967041,-1.6549385786056519,-3.17846941947937,-3.379481315612793,-6.551717281341553,-6.135962963104248,-5.005305767059326,-3.3079042434692383,-2.890045404434204,-9.667242050170898,-8.234289169311523,-3.225403070449829,5.371633529663086,-1.5976349115371704,-1.8039753437042236,-3.0059385299682617,-3.8159730434417725,-5.506833553314209,-3.166529893875122,-3.920804500579834,-3.189967155456543,-10.199725151062012,-1.4589695930480957,-5.0561017990112305,-3.6364946365356445,3.261507749557495,-3.942143201828003,-0.38590142130851746,-4.002687454223633,-7.322124004364014,0.8746180534362793,-3.7112791538238525,0.9486289024353027,-6.890336513519287,-11.35978889465332,-0.39172402024269104,-3.34315824508667,-3.2076053619384766,-3.3020122051239014,-6.552267074584961,-4.371270656585693,-1.3873631954193115,-8.104337692260742,-6.738185882568359,-4.420600891113281,-2.3869807720184326,-4.335232734680176,-3.8771588802337646,-7.932250022888184,-8.98894214630127,-4.468912124633789,-4.877164840698242,-4.864356517791748,-2.644649028778076,-5.553974628448486,-5.350981712341309,-3.8699891567230225,-1.6623440980911255,-5.82854700088501,-4.541965484619141,-5.245368957519531,-3.800689697265625,-1.9194004535675049,-7.784780979156494,2.179626226425171,-0.8652533292770386,-3.460940361022949,0.12991736829280853,0.6788260340690613,-3.1977100372314453,-6.3443922996521,-0.6451369524002075,-1.2773560285568237,-1.0359153747558594,-0.8053964376449585,-4.009747505187988,-3.6893625259399414,-8.016755104064941,-0.35962918400764465,0.8631155490875244,-4.045556545257568,-3.2375452518463135,0.1465379297733307,-1.7902928590774536,-7.37217903137207,-5.695961952209473,-2.6096444129943848,-3.132667303085327,-1.0033706426620483,-4.721982002258301,-0.3320215046405792,-8.186038970947266,-1.1312178373336792,-2.645822048187256,-5.667112350463867,-4.7012763023376465,-1.6262638568878174,-4.917867183685303,-0.0451873354613781,-3.2056939601898193,0.6599360108375549,-7.032112121582031,-0.37890976667404175,-4.609297752380371,-1.861934781074524,-5.630856513977051,-2.275723457336426,-5.645928382873535,3.995225429534912,-4.932981491088867,-4.151825428009033,-2.931499481201172,-4.815249443054199,1.579388976097107,-4.360211372375488,-3.1397759914398193,-5.800182819366455,-7.950736999511719,-4.642892360687256,-5.882481098175049,-6.063215255737305,-3.8543124198913574,-2.4611480236053467,-4.655180931091309,-4.609587669372559,-5.915658473968506,-5.9522705078125,-2.3901641368865967,-1.5379372835159302,2.2016665935516357,-2.633852243423462,-4.149305820465088,-7.288294792175293,-5.719828128814697,-5.900609493255615,-3.056290626525879,-3.266402006149292,-6.129669189453125,-3.026498794555664,-4.565773963928223,-4.204959869384766,-5.718564987182617,0.37380552291870117,-6.455715179443359,-4.499913692474365,-2.419278860092163,-0.19806531071662903,-6.89011812210083,-6.4268059730529785,-5.364577770233154,-3.843982219696045,-1.1714965105056763,-7.28834342956543,-4.513636112213135,-9.65150260925293,-2.143627643585205,-6.822683334350586,0.280985563993454,-2.8304972648620605,-6.328885555267334,4.264336585998535,-0.822444 ...

# %%
import plotly.express as px
from kaleido.scopes.plotly import PlotlyScope

embedding = adata.obsm['emb_pca']
mclust_labels = adata.obs["mclust"]

fig = px.scatter_3d(
    embedding,
    x=0,
    y=1,
    z=2,
    color=mclust_labels,
    title="3D Embedding with GENESPAT",
)

fig.write_html("3d_embedding.html")

fig.show()

scope = PlotlyScope()
img_bytes = scope.transform(fig, format="png", width=800, height=600, scale=2.0)
with open("3d_embedding.png", "wb") as f:
    f.write(img_bytes)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="37555f75-ae1b-4326-b14b-7c63e73c6b3b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37555f75-ae1b-4326-b14b-7c63e73c6b3b")) {                    Plotly.newPlot(                        "37555f75-ae1b-4326-b14b-7c63e73c6b3b",                        [{"hovertemplate":"color=3\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"3","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"3","scene":"scene","showlegend":true,"x":[-5.972431659698486,-0.3925771415233612,0.6573832631111145,0.30821922421455383,-0.22759370505809784,-0.4542115032672882,-0.16304613649845123,0.3346748352050781,2.6191909313201904,3.5505008697509766,0.1604146808385849,1.7120290994644165,5.054620742797852,3.574812173843384,2.789764881134033,4.612686634063721,5.7379231452941895,1.345853567123413,-1.764411211013794,-4.774282932281494,-1.3319969177246094,-6.269333362579346,4.174361228942871,4.8922553062438965,3.2129900455474854,0.12017180770635605,9.342399597167969,-3.643845319747925,-1.7929364442825317,2.314298629760742,1.2540946006774902,1.1586631536483765,0.8373692035675049,2.6200520992279053,3.6529414653778076,1.550880789756775,3.3631718158721924,-4.676898956298828,-1.089195728302002,0.500782310962677,3.491328477859497,6.434786319732666,-3.5924642086029053,2.6087448596954346,2.2796695232391357,-3.360913038253784,0.09392592310905457,5.326277256011963,2.767561912536621,2.1904101371765137,-0.13365913927555084,2.0538980960845947,9.66309928894043,1.7003192901611328,-6.585470676422119,3.2611122131347656,0.6174749732017517,3.056872606277466,3.804717540740967,-6.65609073638916,-4.062807559967041,-1.972111701965332,5.912363052368164,-3.937025308609009,1.3623236417770386,-1.9688020944595337,0.4560748040676117,-0.08748205751180649,4.140536785125732,5.3016743659973145,2.8504831790924072,7.409327507019043,9.224846839904785,3.3264925479888916,-3.4035110473632812,0.7847199440002441,6.752394676208496,-1.6549385786056519,0.9809648990631104,-1.1304360628128052,-5.675787925720215,2.92659068107605,4.952114105224609,2.469709873199463,1.6902213096618652,-2.7742388248443604,2.0678491592407227,-0.9252564907073975,3.917085886001587,3.939720869064331,2.089280128479004,-3.626133441925049,-2.127394199371338,4.219241142272949,2.254673957824707,-2.6176252365112305,-0.3705867528915405,6.987752914428711,-5.3101887702941895,2.545192003250122,6.838776111602783,-5.870763778686523,7.9636945724487305,0.6938964128494263,5.349637508392334,2.7921299934387207,9.308362007141113,3.5676867961883545,-4.860501289367676,-2.153225898742676,2.625962257385254,8.37458610534668,-2.406076431274414,-2.146470546722412,3.2777016162872314,3.0985546112060547,1.8015047311782837,-2.1646060943603516,-3.17846941947937,5.294589519500732,8.383218765258789,-1.7065935134887695,1.7216129302978516,-1.5134127140045166,4.259424686431885,5.658075332641602,-3.379481315612793,-0.6705891489982605,-6.551717281341553,1.8990370035171509,1.5610069036483765,-6.135962963104248,-5.463419437408447,2.253235340118408,2.8419620990753174,0.978452742099762,-0.557636022567749,6.428816795349121,-5.005305767059326,-3.3079042434692383,-7.573504447937012,-0.8433219194412231,4.325644016265869,4.47498083114624,1.749975323677063,3.699263334274292,-5.615291595458984,2.1758480072021484,-0.12552502751350403,3.0752646923065186,3.743971586227417,-0.18538373708724976,-0.2767714262008667,-0.13340306282043457,0.013906084932386875,7.786925315856934,-0.11645905673503876,6.744808673858643,2.032896041870117,-1.9772521257400513,-2.603482484817505,4.893558502197266,1.9750698804855347,1.4709059000015259,0.4164898097515106,-2.890045404434204,-2.1376750469207764,-9.667242050170898, ...

# %%
import plotly.express as px
from kaleido.scopes.plotly import PlotlyScope

embedding = adata.obsm['emb_pca']
mclust_labels = adata.obs["Ground_Truth"]

fig = px.scatter_3d(
    embedding,
    x=0,
    y=1,
    z=2,
    color=mclust_labels,
    title="3D Embedding with Ground Truth Clustering",
)

fig.write_html("3d_embedding.html")

fig.show()

scope = PlotlyScope()
img_bytes = scope.transform(fig, format="png", width=800, height=600, scale=2.0)
with open("3d_embedding.png", "wb") as f:
    f.write(img_bytes)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d5a732bd-7c32-43bb-aa94-70574a92c369" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d5a732bd-7c32-43bb-aa94-70574a92c369")) {                    Plotly.newPlot(                        "d5a732bd-7c32-43bb-aa94-70574a92c369",                        [{"hovertemplate":"color=Layer4\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Layer4","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Layer4","scene":"scene","showlegend":true,"x":[-5.972431659698486,0.6573832631111145,-3.360913038253784,-4.062807559967041,-1.6549385786056519,-3.17846941947937,-3.379481315612793,-6.551717281341553,-6.135962963104248,-5.005305767059326,-3.3079042434692383,-2.890045404434204,-9.667242050170898,-8.234289169311523,-3.225403070449829,5.371633529663086,-1.5976349115371704,-1.8039753437042236,-3.0059385299682617,-3.8159730434417725,-5.506833553314209,-3.166529893875122,-3.920804500579834,-3.189967155456543,-10.199725151062012,-1.4589695930480957,-5.0561017990112305,-3.6364946365356445,3.261507749557495,-3.942143201828003,-0.38590142130851746,-4.002687454223633,-7.322124004364014,0.8746180534362793,-3.7112791538238525,0.9486289024353027,-6.890336513519287,-11.35978889465332,-0.39172402024269104,-3.34315824508667,-3.2076053619384766,-3.3020122051239014,-6.552267074584961,-4.371270656585693,-1.3873631954193115,-8.104337692260742,-6.738185882568359,-4.420600891113281,-2.3869807720184326,-4.335232734680176,-3.8771588802337646,-7.932250022888184,-8.98894214630127,-4.468912124633789,-4.877164840698242,-4.864356517791748,-2.644649028778076,-5.553974628448486,-5.350981712341309,-3.8699891567230225,-1.6623440980911255,-5.82854700088501,-4.541965484619141,-5.245368957519531,-3.800689697265625,-1.9194004535675049,-7.784780979156494,2.179626226425171,-0.8652533292770386,-3.460940361022949,0.12991736829280853,0.6788260340690613,-3.1977100372314453,-6.3443922996521,-0.6451369524002075,-1.2773560285568237,-1.0359153747558594,-0.8053964376449585,-4.009747505187988,-3.6893625259399414,-8.016755104064941,-0.35962918400764465,0.8631155490875244,-4.045556545257568,-3.2375452518463135,0.1465379297733307,-1.7902928590774536,-7.37217903137207,-5.695961952209473,-2.6096444129943848,-3.132667303085327,-1.0033706426620483,-4.721982002258301,-0.3320215046405792,-8.186038970947266,-1.1312178373336792,-2.645822048187256,-5.667112350463867,-4.7012763023376465,-1.6262638568878174,-4.917867183685303,-0.0451873354613781,-3.2056939601898193,0.6599360108375549,-7.032112121582031,-0.37890976667404175,-4.609297752380371,-1.861934781074524,-5.630856513977051,-2.275723457336426,-5.645928382873535,3.995225429534912,-4.932981491088867,-4.151825428009033,-2.931499481201172,-4.815249443054199,1.579388976097107,-4.360211372375488,-3.1397759914398193,-5.800182819366455,-7.950736999511719,-4.642892360687256,-5.882481098175049,-6.063215255737305,-3.8543124198913574,-2.4611480236053467,-4.655180931091309,-4.609587669372559,-5.915658473968506,-5.9522705078125,-2.3901641368865967,-1.5379372835159302,2.2016665935516357,-2.633852243423462,-4.149305820465088,-7.288294792175293,-5.719828128814697,-5.900609493255615,-3.056290626525879,-3.266402006149292,-6.129669189453125,-3.026498794555664,-4.565773963928223,-4.204959869384766,-5.718564987182617,0.37380552291870117,-6.455715179443359,-4.499913692474365,-2.419278860092163,-0.19806531071662903,-6.89011812210083,-6.4268059730529785,-5.364577770233154,-3.843982219696045,-1.1714965105056763,-7.28834342956543,-4.513636112213135,-9.65150260925293,-2.143627643585205,-6.822683334350586,0.280985563993454,-2.8304972648620605,-6.328885555267334,4.264336585998535,-0.822444 ...

# %%
ARI = metrics.adjusted_rand_score(adata.obs['mclust'], adata.obs['Ground_Truth'])
adata.uns['ARI'] = ARI
print('ARI:', ARI)
# Out:
# ARI: 0.6243545918085249

# %%
sc.pl.spatial(adata,
              img_key="hires",
              color=["Ground_Truth", "mclust"],
              title=["Ground_Truth", "ARI=%.4f"%ARI],
              show=True)
