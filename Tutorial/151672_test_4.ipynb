# %%
import anndata
import scanpy as sc
from sklearn import metrics
import matplotlib as mpl
from matplotlib import pyplot as plt
import numpy as np
import plotly.express as px

adata = anndata.read_h5ad(filename='Tutorial/all_adatas/151672_adata.h5ad')

# %%
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 3888 × 33538
#     obs: 'in_tissue', 'array_row', 'array_col', 'imagecol', 'imagerow', 'slices_path', 'Ground_Truth', 'mclust'
#     var: 'gene_ids', 'feature_types', 'genome', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'mean', 'std'
#     uns: 'ARI', 'Ground_Truth_colors', 'hvg', 'log1p', 'mclust_colors', 'neighbors', 'spatial'
#     obsm: 'adj', 'combined_feat', 'distance_matrix', 'emb', 'emb_pca', 'feat_a', 'graph_neigh', 'image_feat', 'label_CSL', 'spatial'
#     obsp: 'connectivities', 'distances'

# %%
sc.pl.highest_expr_genes(adata, n_top=20)

# %%
cell_index = 0
gene_expression = adata.X[cell_index]
expressed_gene_indices = gene_expression.nonzero()[1]
expressed_genes = adata.var_names[expressed_gene_indices]
print(expressed_genes)
# Out:
# Index(['HES4', 'ISG15', 'AGRN', 'UBE2J2', 'AURKAIP1', 'GNB1', 'GABRD', 'PRKCZ',
#        'FAAP20', 'RER1',
#        ...
#        'MT-CO1', 'MT-CO2', 'MT-ATP8', 'MT-ATP6', 'MT-CO3', 'MT-ND3', 'MT-ND4L',
#        'MT-ND4', 'MT-ND5', 'MT-CYB'],
#       dtype='object', length=2286)

# %%
with mpl.rc_context({'figure.figsize': [6, 7], 'axes.facecolor': 'black'}):
    sc.pl.spatial(adata,
                  color=[ "HES4","SDF4", "CPTP"],
                  img_key=None,
                  size=1,
                  vmin=0,
                  cmap='magma',
                  vmax='p99.0',
                  gene_symbols='SYMBOL'
                 )

# %%
gene_counts_sum = np.sum(adata.X, axis=0)
gene_with_most_counts = adata.var_names[np.argmax(gene_counts_sum)]
print("Gene with the most counts:", gene_with_most_counts)
# Out:
# Gene with the most counts: MT-CO1

# %%
sc.tl.umap(adata, n_components=2)
sc.pl.umap(adata)

# %%
sc.tl.diffmap(adata)

# %%
sc.pl.diffmap(adata, color='mclust')

# %%
sc.pl.diffmap(adata, color='Ground_Truth')

# %%
sc.tl.draw_graph(adata)
# Out:
# WARNING: Package 'fa2' is not installed, falling back to layout 'fr'.To use the faster and better ForceAtlas2 layout, install package 'fa2' (`pip install fa2`).

# %%
sc.pl.draw_graph(adata, color=['Ground_Truth', 'mclust'])

# %%
sc.pl.umap(adata, color=["HES4", "SDF4", "CPTP"])

# %%
plt.rcParams["figure.figsize"] = (4, 4)
sc.pl.umap(adata, color=["mclust"], wspace=0.4)

# %%
sc.pl.highly_variable_genes(adata)

# %%
sc.pp.pca(adata)

# %%
sc.pl.pca_variance_ratio(adata, log=True)

# %%
sc.tl.rank_genes_groups(adata, "mclust", method="t-test")

# %%
sc.pl.rank_genes_groups(adata, n_genes=10)

# %%
result = adata.uns["rank_genes_groups"]
groups = result["names"].dtype.names
top_features = {}
n_top_genes = 10
for group in groups:
    top_features[group] = result["names"][group][:n_top_genes]

for group, features in top_features.items():
    print(f"Cluster {group} top features:")
    for feature in features:
        print(feature)
    print()
# Out:
# Cluster 1 top features:
# MBP
# PLP1
# SCGB2A2
# GFAP
# DIRAS2
# KRT17
# B3GALT2
# SLC17A7
# MAP2K1
# SCGB1D2
#
# Cluster 2 top features:
# HPCAL1
# SAA1
# FABP4
# CAMK2N1
# MT-ND3
# HOPX
# ENC1
# CARTPT
# MT-ATP8
# CKB
#
# Cluster 3 top features:
# SCGB2A2
# SCGB1D2
# KRT8
# S100A11
# MUC1
# KRT19
# AGR2
# COL1A1
# GFAP
# KRT18
#
# Cluster 4 top features:
# NDUFA4
# NRGN
# HOPX
# MT-ND5
# MTRNR2L8
# MT-ND4L
# MT3
# MT-ATP8
# NEFM
# SNCG
#
# Cluster 5 top features:
# PCP4
# TMSB10
# SYT1
# STMN1
# TUBB2A
# TUBA1B
# SNAP25
# SNRPN
# COX7A1
# TTC9B

# %%
embedding = adata.obsm['emb_pca']
mclust_labels = adata.obs["mclust"]

fig = px.scatter_3d(
    embedding,
    x=0,
    y=1,
    z=2,
    color=mclust_labels,
    title="3D Embedding with GENESPAT",
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="789cea03-0e21-41d3-aef8-3dcd05d32547" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("789cea03-0e21-41d3-aef8-3dcd05d32547")) {                    Plotly.newPlot(                        "789cea03-0e21-41d3-aef8-3dcd05d32547",                        [{"hovertemplate":"color=5\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"5","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"5","scene":"scene","showlegend":true,"x":[-4.51071834564209,-0.9189354181289673,-6.1652631759643555,-7.2024431228637695,-0.6557108759880066,-2.9010112285614014,-2.852200508117676,-4.629870414733887,-9.691081047058105,-4.77441930770874,-1.0801805257797241,-5.476616382598877,-5.231710433959961,-8.928580284118652,-4.4010443687438965,-1.6045819520950317,-7.006430625915527,-8.114307403564453,1.564390778541565,-3.2074732780456543,-3.5947089195251465,-0.5671454071998596,0.3691582977771759,-5.994164943695068,-1.3139715194702148,-3.8441402912139893,-2.517434597015381,-2.7076430320739746,-3.4804718494415283,-4.747038841247559,-6.838223457336426,-6.683938980102539,-3.3111839294433594,-7.916298866271973,-0.7553516626358032,-5.997106552124023,-3.733846426010132,-3.5165412425994873,-6.775380611419678,-3.760868549346924,-6.4725542068481445,-2.977416515350342,-6.0146074295043945,-7.636282920837402,-8.125988960266113,-2.778437852859497,0.9088435173034668,-2.9405648708343506,-2.561063051223755,-3.0782363414764404,-4.622836112976074,-3.7300431728363037,-8.75493049621582,-4.069502353668213,2.526721715927124,-5.8576836585998535,-2.3616442680358887,-4.730434417724609,0.201371967792511,-4.773488998413086,-7.494912147521973,-4.388297080993652,-3.482302188873291,-2.9916419982910156,-3.3337860107421875,-0.2608819305896759,-2.3441240787506104,-0.9855786561965942,-5.760423183441162,-1.7581517696380615,-5.010251522064209,-1.208444356918335,-2.159146308898926,-1.0665276050567627,-2.5870375633239746,-1.8403435945510864,-1.5068520307540894,-3.0416672229766846,-4.139582633972168,-4.39993143081665,-3.0242791175842285,1.2622687816619873,-4.42724609375,-1.1108174324035645,-8.15274429321289,-2.557500123977661,-9.93182373046875,-2.509568929672241,-5.199216365814209,-7.424192905426025,0.15924006700515747,-6.202906608581543,-3.3836350440979004,-6.34759521484375,-4.159964561462402,1.88824462890625,-1.7048553228378296,-3.9165449142456055,-1.8705153465270996,-1.1866754293441772,1.631961703300476,-6.136053085327148,-2.9202170372009277,-2.1790966987609863,-3.4001529216766357,-4.044575214385986,-3.9062397480010986,-6.9682297706604,-2.1288163661956787,-4.435756683349609,-3.694080114364624,-4.854696750640869,0.4379534125328064,-6.421036243438721,-7.91011381149292,4.306416034698486,4.07383918762207,-4.436924457550049,-6.267338275909424,-0.41702526807785034,1.5320287942886353,-0.20411372184753418,-8.089883804321289,-5.304745197296143,-3.9628803730010986,-6.033743858337402,-4.481670379638672,0.5592626929283142,0.20168045163154602,-4.52286958694458,-5.259194374084473,-0.8845613598823547,-6.735789775848389,-2.8317413330078125,-3.7740578651428223,-3.327662944793701,-1.6710195541381836,-4.861320495605469,0.8924985527992249,-3.8028597831726074,-3.60398268699646,0.021074511110782623,-5.15723991394043,-7.207579612731934,-3.3308424949645996,-5.703864097595215,-4.2889909744262695,-4.459958076477051,-5.186779975891113,-2.8261337280273438,-5.1366424560546875,-2.5054476261138916,-10.329171180725098,-4.421036243438721,0.2248574048280716,-7.653626918792725,-6.537766456604004,-1.9685466289520264,-0.051565829664468765,-3.9498023986816406,3.946525812149048,-2.8724262714385986,-7.622321128845215,-6.623228549957275,-2.00194263458 ...

# %%
embedding = adata.obsm['emb_pca']
mclust_labels = adata.obs["Ground_Truth"]

fig = px.scatter_3d(
    embedding,
    x=0,
    y=1,
    z=2,
    color=mclust_labels,
    title="3D Embedding with Ground Truth Clustering",
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5073caf0-d1ad-4441-af2f-531a3b2438f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5073caf0-d1ad-4441-af2f-531a3b2438f0")) {                    Plotly.newPlot(                        "5073caf0-d1ad-4441-af2f-531a3b2438f0",                        [{"hovertemplate":"color=Layer5\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Layer5","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Layer5","scene":"scene","showlegend":true,"x":[-4.51071834564209,-0.9189354181289673,-6.1652631759643555,-7.2024431228637695,-0.6557108759880066,-4.629870414733887,0.5077869892120361,-9.691081047058105,-4.77441930770874,-5.476616382598877,-5.231710433959961,-8.928580284118652,-4.4010443687438965,-1.6045819520950317,-7.006430625915527,-8.114307403564453,-3.5947089195251465,-0.5671454071998596,0.3691582977771759,-1.3139715194702148,-3.8441402912139893,-2.517434597015381,-2.7076430320739746,-4.747038841247559,-6.683938980102539,-3.3111839294433594,-7.916298866271973,-0.7553516626358032,-5.997106552124023,-3.733846426010132,-3.5165412425994873,-6.775380611419678,-3.760868549346924,-2.977416515350342,-6.0146074295043945,-7.636282920837402,-8.125988960266113,-2.778437852859497,-2.9405648708343506,-6.425940990447998,-4.622836112976074,-7.641699314117432,-8.75493049621582,-5.8576836585998535,-2.3616442680358887,-4.730434417724609,0.201371967792511,-4.773488998413086,-4.388297080993652,-2.9916419982910156,-3.3337860107421875,-0.2608819305896759,-8.443984985351562,-5.760423183441162,-1.7581517696380615,-5.010251522064209,-1.208444356918335,-2.159146308898926,-1.0665276050567627,-1.5068520307540894,-4.139582633972168,-4.39993143081665,-4.42724609375,-1.1108174324035645,-8.15274429321289,-2.557500123977661,-9.93182373046875,-2.509568929672241,-6.202906608581543,2.7011702060699463,-3.3836350440979004,-6.34759521484375,-4.159964561462402,-1.8705153465270996,-1.1866754293441772,-9.563072204589844,-6.136053085327148,-2.9202170372009277,-3.4001529216766357,-4.044575214385986,-3.9062397480010986,-6.9682297706604,-2.1288163661956787,-4.435756683349609,-3.694080114364624,0.4379534125328064,-6.421036243438721,-4.436924457550049,-6.267338275909424,-0.41702526807785034,-8.089883804321289,-5.304745197296143,-3.9628803730010986,-4.481670379638672,0.5592626929283142,0.20168045163154602,0.21809260547161102,-4.712751865386963,-4.52286958694458,-5.259194374084473,-10.769104957580566,-6.735789775848389,-2.8317413330078125,-3.7740578651428223,-3.327662944793701,-1.6710195541381836,-3.60398268699646,0.021074511110782623,-5.15723991394043,-7.207579612731934,-4.2889909744262695,-4.459958076477051,-5.186779975891113,-2.8261337280273438,-2.5054476261138916,-10.329171180725098,-4.421036243438721,-7.653626918792725,-6.537766456604004,-1.9685466289520264,-0.051565829664468765,-3.629912853240967,-2.8724262714385986,-6.623228549957275,-2.0019426345825195,-2.0868442058563232,-5.306532382965088,-3.0232882499694824,-4.023916721343994,-5.031694412231445,-5.647800922393799,-5.877607822418213,-1.1125900745391846,-2.09721302986145,-7.715630054473877,-3.517984390258789,-3.9961612224578857,-8.836569786071777,-6.149081230163574,-10.084137916564941,-8.892069816589355,-2.7898404598236084,-4.0547099113464355,-2.6952970027923584,-3.3703439235687256,-5.369295597076416,-2.5433433055877686,-5.6205549240112305,-4.485678195953369,-4.687554359436035,-4.612485408782959,1.213976263999939,-2.909590721130371,-3.3858578205108643,-6.0973310470581055,0.5478545427322388,-8.942252159118652,-1.8282581567764282,-1.8260111808776855,-6.650380611419678,-3.1813547611236572,-8.182958602905273,-0.5965703725814819,-6.08920812606 ...

# %%
import plotly.express as px
from kaleido.scopes.plotly import PlotlyScope

embedding = adata.obsm['emb_pca']
mclust_labels = adata.obs["mclust"]

fig = px.scatter_3d(
    embedding,
    x=0,
    y=1,
    z=2,
    color=mclust_labels,
    title="3D Embedding with GENESPAT",
)

fig.write_html("3d_embedding.html")

fig.show()

scope = PlotlyScope()
img_bytes = scope.transform(fig, format="png", width=800, height=600, scale=2.0)
with open("3d_embedding.png", "wb") as f:
    f.write(img_bytes)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e96a68ae-394d-4b78-94a5-99d621d51dec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e96a68ae-394d-4b78-94a5-99d621d51dec")) {                    Plotly.newPlot(                        "e96a68ae-394d-4b78-94a5-99d621d51dec",                        [{"hovertemplate":"color=5\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"5","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"5","scene":"scene","showlegend":true,"x":[-4.51071834564209,-0.9189354181289673,-6.1652631759643555,-7.2024431228637695,-0.6557108759880066,-2.9010112285614014,-2.852200508117676,-4.629870414733887,-9.691081047058105,-4.77441930770874,-1.0801805257797241,-5.476616382598877,-5.231710433959961,-8.928580284118652,-4.4010443687438965,-1.6045819520950317,-7.006430625915527,-8.114307403564453,1.564390778541565,-3.2074732780456543,-3.5947089195251465,-0.5671454071998596,0.3691582977771759,-5.994164943695068,-1.3139715194702148,-3.8441402912139893,-2.517434597015381,-2.7076430320739746,-3.4804718494415283,-4.747038841247559,-6.838223457336426,-6.683938980102539,-3.3111839294433594,-7.916298866271973,-0.7553516626358032,-5.997106552124023,-3.733846426010132,-3.5165412425994873,-6.775380611419678,-3.760868549346924,-6.4725542068481445,-2.977416515350342,-6.0146074295043945,-7.636282920837402,-8.125988960266113,-2.778437852859497,0.9088435173034668,-2.9405648708343506,-2.561063051223755,-3.0782363414764404,-4.622836112976074,-3.7300431728363037,-8.75493049621582,-4.069502353668213,2.526721715927124,-5.8576836585998535,-2.3616442680358887,-4.730434417724609,0.201371967792511,-4.773488998413086,-7.494912147521973,-4.388297080993652,-3.482302188873291,-2.9916419982910156,-3.3337860107421875,-0.2608819305896759,-2.3441240787506104,-0.9855786561965942,-5.760423183441162,-1.7581517696380615,-5.010251522064209,-1.208444356918335,-2.159146308898926,-1.0665276050567627,-2.5870375633239746,-1.8403435945510864,-1.5068520307540894,-3.0416672229766846,-4.139582633972168,-4.39993143081665,-3.0242791175842285,1.2622687816619873,-4.42724609375,-1.1108174324035645,-8.15274429321289,-2.557500123977661,-9.93182373046875,-2.509568929672241,-5.199216365814209,-7.424192905426025,0.15924006700515747,-6.202906608581543,-3.3836350440979004,-6.34759521484375,-4.159964561462402,1.88824462890625,-1.7048553228378296,-3.9165449142456055,-1.8705153465270996,-1.1866754293441772,1.631961703300476,-6.136053085327148,-2.9202170372009277,-2.1790966987609863,-3.4001529216766357,-4.044575214385986,-3.9062397480010986,-6.9682297706604,-2.1288163661956787,-4.435756683349609,-3.694080114364624,-4.854696750640869,0.4379534125328064,-6.421036243438721,-7.91011381149292,4.306416034698486,4.07383918762207,-4.436924457550049,-6.267338275909424,-0.41702526807785034,1.5320287942886353,-0.20411372184753418,-8.089883804321289,-5.304745197296143,-3.9628803730010986,-6.033743858337402,-4.481670379638672,0.5592626929283142,0.20168045163154602,-4.52286958694458,-5.259194374084473,-0.8845613598823547,-6.735789775848389,-2.8317413330078125,-3.7740578651428223,-3.327662944793701,-1.6710195541381836,-4.861320495605469,0.8924985527992249,-3.8028597831726074,-3.60398268699646,0.021074511110782623,-5.15723991394043,-7.207579612731934,-3.3308424949645996,-5.703864097595215,-4.2889909744262695,-4.459958076477051,-5.186779975891113,-2.8261337280273438,-5.1366424560546875,-2.5054476261138916,-10.329171180725098,-4.421036243438721,0.2248574048280716,-7.653626918792725,-6.537766456604004,-1.9685466289520264,-0.051565829664468765,-3.9498023986816406,3.946525812149048,-2.8724262714385986,-7.622321128845215,-6.623228549957275,-2.00194263458 ...

# %%
ARI = metrics.adjusted_rand_score(adata.obs['mclust'], adata.obs['Ground_Truth'])
adata.uns['ARI'] = ARI
print('ARI:', ARI)
# Out:
# ARI: 0.6272737613044478

# %%
sc.pl.spatial(adata,
              img_key="hires",
              color=["Ground_Truth", "mclust"],
              title=["Ground_Truth", "ARI=%.4f"%ARI],
              show=True)
