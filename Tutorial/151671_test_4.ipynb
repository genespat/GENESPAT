# %%
import anndata
import scanpy as sc
from sklearn import metrics
import matplotlib as mpl
from matplotlib import pyplot as plt
import numpy as np
import plotly.express as px

adata = anndata.read_h5ad(filename='Tutorial/all_adatas/151671_adata.h5ad')

# %%
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 4093 × 33538
#     obs: 'in_tissue', 'array_row', 'array_col', 'imagecol', 'imagerow', 'slices_path', 'Ground_Truth', 'mclust'
#     var: 'gene_ids', 'feature_types', 'genome', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'mean', 'std'
#     uns: 'ARI', 'Ground_Truth_colors', 'hvg', 'log1p', 'mclust_colors', 'neighbors', 'spatial'
#     obsm: 'adj', 'combined_feat', 'distance_matrix', 'emb', 'emb_pca', 'feat_a', 'graph_neigh', 'image_feat', 'label_CSL', 'spatial'
#     obsp: 'connectivities', 'distances'

# %%
sc.pl.highest_expr_genes(adata, n_top=20)

# %%
cell_index = 0
gene_expression = adata.X[cell_index]
expressed_gene_indices = gene_expression.nonzero()[1]
expressed_genes = adata.var_names[expressed_gene_indices]
print(expressed_genes)
# Out:
# Index(['NOC2L', 'HES4', 'AGRN', 'SDF4', 'DVL1', 'AURKAIP1', 'MRPL20', 'ATAD3B',
#        'SSU72', 'GNB1',
#        ...
#        'MT-ATP8', 'MT-ATP6', 'MT-CO3', 'MT-ND3', 'MT-ND4L', 'MT-ND4', 'MT-ND5',
#        'MT-ND6', 'MT-CYB', 'AC007325.4'],
#       dtype='object', length=3646)

# %%
with mpl.rc_context({'figure.figsize': [6, 7], 'axes.facecolor': 'black'}):
    sc.pl.spatial(adata,
                  color=[ "HES4","SDF4", "CPTP"],
                  img_key=None,
                  size=1,
                  vmin=0,
                  cmap='magma',
                  vmax='p99.0',
                  gene_symbols='SYMBOL'
                 )

# %%
gene_counts_sum = np.sum(adata.X, axis=0)
gene_with_most_counts = adata.var_names[np.argmax(gene_counts_sum)]
print("Gene with the most counts:", gene_with_most_counts)
# Out:
# Gene with the most counts: MT-CO1

# %%
sc.tl.umap(adata, n_components=2)
sc.pl.umap(adata)

# %%
sc.tl.diffmap(adata)

# %%
sc.pl.diffmap(adata, color='mclust')

# %%
sc.pl.diffmap(adata, color='Ground_Truth')

# %%
sc.tl.draw_graph(adata)
# Out:
# WARNING: Package 'fa2' is not installed, falling back to layout 'fr'.To use the faster and better ForceAtlas2 layout, install package 'fa2' (`pip install fa2`).

# %%
sc.pl.draw_graph(adata, color=['Ground_Truth', 'mclust'])

# %%
sc.pl.umap(adata, color=["HES4", "SDF4", "CPTP"])

# %%
plt.rcParams["figure.figsize"] = (4, 4)
sc.pl.umap(adata, color=["mclust"], wspace=0.4)

# %%
sc.pl.highly_variable_genes(adata)

# %%
sc.pp.pca(adata)

# %%
sc.pl.pca_variance_ratio(adata, log=True)

# %%
sc.tl.rank_genes_groups(adata, "mclust", method="t-test")

# %%
sc.pl.rank_genes_groups(adata, n_genes=10)

# %%
result = adata.uns["rank_genes_groups"]
groups = result["names"].dtype.names
top_features = {}
n_top_genes = 10
for group in groups:
    top_features[group] = result["names"][group][:n_top_genes]

for group, features in top_features.items():
    print(f"Cluster {group} top features:")
    for feature in features:
        print(feature)
    print()
# Out:
# Cluster 1 top features:
# SAA1
# FABP4
# CAMK2N1
# MT-ATP8
# MT-ND3
# MT-ND5
# HPCAL1
# G0S2
# ENC1
# HOPX
#
# Cluster 2 top features:
# MBP
# PLP1
# SCGB2A2
# DIRAS2
# GPM6A
# GFAP
# B3GALT2
# SLC17A7
# CRYAB
# SYT1
#
# Cluster 3 top features:
# PCP4
# TMSB10
# SYT1
# SNAP25
# STMN1
# COX7A1
# TUBB2A
# TUBA1B
# NDRG4
# SNRPN
#
# Cluster 4 top features:
# MT-ND3
# MT3
# NRGN
# MTRNR2L8
# MT-ND5
# CST3
# PCSK1N
# MT-ND4L
# NDUFA4
# NEFM
#
# Cluster 5 top features:
# SCGB2A2
# SCGB1D2
# S100A11
# KRT8
# MUC1
# KRT18
# KRT19
# COL1A2
# AGR2
# RPLP1

# %%
embedding = adata.obsm['emb_pca']
mclust_labels = adata.obs["mclust"]

fig = px.scatter_3d(
    embedding,
    x=0,
    y=1,
    z=2,
    color=mclust_labels,
    title="3D Embedding with GENESPAT",
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cff73277-ac2f-43a4-bad1-1e3697273970" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cff73277-ac2f-43a4-bad1-1e3697273970")) {                    Plotly.newPlot(                        "cff73277-ac2f-43a4-bad1-1e3697273970",                        [{"hovertemplate":"color=3\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"3","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"3","scene":"scene","showlegend":true,"x":[-4.96307897567749,-2.7418875694274902,-6.990638256072998,-6.108727931976318,-4.996501445770264,-3.7364749908447266,-5.523031234741211,-2.4084980487823486,-0.4380231201648712,-2.9132490158081055,-5.7701544761657715,-5.305004119873047,-7.600839614868164,-4.539161682128906,-8.948527336120605,-5.383172988891602,-3.552248477935791,-5.899576663970947,-3.0388426780700684,-3.7135016918182373,-6.842713356018066,-1.1551364660263062,5.2287797927856445,-6.6882524490356445,-0.4380662143230438,-7.431769371032715,-7.249168395996094,-5.36077880859375,-0.32442009449005127,-5.970727920532227,-5.800305366516113,-10.304497718811035,-1.099179744720459,-3.9580729007720947,-2.6244618892669678,-3.330876111984253,-2.910287857055664,-2.0475430488586426,-5.8668599128723145,-5.135390758514404,-3.1864943504333496,-2.9256086349487305,-8.152486801147461,-8.283099174499512,-6.443780422210693,-8.013832092285156,1.86614191532135,-6.885595798492432,-6.932252883911133,-1.6109338998794556,-7.930479049682617,1.9232892990112305,-7.492140293121338,-5.505044937133789,-0.5497979521751404,-9.353102684020996,-8.078034400939941,-6.598191738128662,-4.183879852294922,-8.024128913879395,-2.6334023475646973,-7.592875957489014,-8.021029472351074,-8.28459644317627,-7.732846736907959,-3.4874038696289062,-7.357230186462402,-5.73326301574707,-1.514732003211975,-7.457437038421631,-1.6735916137695312,-8.601502418518066,-6.2273783683776855,-6.322330474853516,-8.152761459350586,-0.7163372039794922,-6.7755537033081055,-5.966793537139893,-3.0975749492645264,-6.685412883758545,-7.848785877227783,-1.7726225852966309,-4.002461910247803,-4.21584415435791,-10.527427673339844,-5.060801029205322,-2.114302635192871,-4.896928310394287,-8.747027397155762,-3.4787559509277344,-8.819662094116211,-3.6727075576782227,-4.844329833984375,-4.414717674255371,-6.472933769226074,-6.481365203857422,-6.7305989265441895,-3.9427483081817627,-6.5408406257629395,-5.1120429039001465,-2.675039291381836,-3.7038302421569824,-8.290801048278809,-0.2648458480834961,-2.964754343032837,-8.170180320739746,-8.0355806350708,-6.402848720550537,-8.408350944519043,-2.4924654960632324,-2.0497474670410156,-5.330253601074219,-3.433004140853882,-6.971902370452881,-4.2561821937561035,-4.0839128494262695,-4.471527099609375,-7.123473644256592,-7.602591514587402,-6.810490608215332,-2.041048765182495,-5.102437973022461,-1.942883014678955,-5.048992156982422,0.1770125925540924,-4.567780017852783,-5.930119037628174,-9.344797134399414,-4.776395320892334,-6.286082744598389,-4.1638407707214355,-10.311691284179688,-10.045578002929688,0.008486141450703144,-0.8743237257003784,-9.389480590820312,-1.9521983861923218,-5.638360023498535,-3.4137461185455322,-1.7966800928115845,-1.2153810262680054,-1.1594573259353638,-3.666318655014038,-8.079296112060547,-4.066215515136719,-8.079425811767578,-5.145116806030273,-6.020544528961182,0.06232244148850441,-5.275156497955322,-2.099938154220581,-4.916130542755127,-6.643413066864014,-7.924217224121094,-6.1775383949279785,-6.2416768074035645,-6.160669326782227,-1.5585297346115112,-1.1790812015533447,-4.788069248199463,-1.2784651517868042,0.3621830344200134,-0.67684406042099,-2.8543646335601807,-4.5883083 ...

# %%
embedding = adata.obsm['emb_pca']
mclust_labels = adata.obs["Ground_Truth"]

fig = px.scatter_3d(
    embedding,
    x=0,
    y=1,
    z=2,
    color=mclust_labels,
    title="3D Embedding with Ground Truth Clustering",
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="48c2b745-fa5f-4983-9d1d-2df96e32552f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("48c2b745-fa5f-4983-9d1d-2df96e32552f")) {                    Plotly.newPlot(                        "48c2b745-fa5f-4983-9d1d-2df96e32552f",                        [{"hovertemplate":"color=Layer5\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Layer5","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Layer5","scene":"scene","showlegend":true,"x":[-4.96307897567749,-2.7418875694274902,-6.990638256072998,-4.996501445770264,-5.523031234741211,-2.4084980487823486,-2.9132490158081055,-5.305004119873047,-7.600839614868164,-4.539161682128906,-8.948527336120605,-5.899576663970947,-6.842713356018066,-1.1551364660263062,-6.6882524490356445,-7.431769371032715,-7.249168395996094,-0.32442009449005127,-5.970727920532227,-5.800305366516113,-10.304497718811035,-2.6244618892669678,-3.330876111984253,-2.910287857055664,-3.1864943504333496,-8.300239562988281,-6.7077250480651855,-2.9256086349487305,-8.152486801147461,-8.283099174499512,-8.013832092285156,-4.491214275360107,1.86614191532135,-6.885595798492432,-6.932252883911133,-7.930479049682617,-7.492140293121338,-9.353102684020996,-6.598191738128662,-8.024128913879395,-2.6334023475646973,-7.592875957489014,-8.021029472351074,-7.732846736907959,-3.4874038696289062,-7.357230186462402,-5.73326301574707,-1.514732003211975,-7.457437038421631,-1.6735916137695312,-8.601502418518066,-6.2273783683776855,-6.322330474853516,-8.152761459350586,-0.7163372039794922,-6.7755537033081055,-5.966793537139893,-3.0975749492645264,-6.685412883758545,-7.848785877227783,-1.489471673965454,-1.7726225852966309,-8.039204597473145,-10.527427673339844,-5.060801029205322,-4.896928310394287,1.1149262189865112,-1.8002657890319824,-8.747027397155762,-3.4787559509277344,-8.819662094116211,-3.6727075576782227,-4.844329833984375,-6.472933769226074,1.0528252124786377,-6.481365203857422,-6.7305989265441895,-3.9427483081817627,-6.5408406257629395,-5.1120429039001465,-3.5908167362213135,-2.675039291381836,-7.945188522338867,-8.290801048278809,-0.2648458480834961,-8.170180320739746,-8.0355806350708,-6.402848720550537,-8.408350944519043,-2.0497474670410156,-5.330253601074219,-6.971902370452881,-4.2561821937561035,-4.471527099609375,-7.123473644256592,-7.602591514587402,-2.041048765182495,-1.942883014678955,-5.048992156982422,0.1770125925540924,-4.567780017852783,-5.930119037628174,-9.344797134399414,-4.1638407707214355,-10.311691284179688,-10.045578002929688,0.008486141450703144,-4.4299163818359375,-9.389480590820312,-1.9521983861923218,-5.638360023498535,-3.4137461185455322,-1.7966800928115845,-1.2153810262680054,-1.1594573259353638,-3.666318655014038,-8.079296112060547,-4.066215515136719,-8.079425811767578,-6.020544528961182,-4.916130542755127,-6.643413066864014,-7.924217224121094,-6.1775383949279785,-6.2416768074035645,-6.160669326782227,-3.301990509033203,-1.5585297346115112,-1.1790812015533447,-4.788069248199463,-1.2784651517868042,0.3621830344200134,-2.8543646335601807,-4.588308334350586,-9.822088241577148,-6.427197456359863,-5.88417911529541,-3.1857922077178955,-4.88707160949707,-6.129397869110107,-1.208932876586914,-11.424365043640137,-4.041832447052002,-6.5821452140808105,-5.3412909507751465,-4.050982475280762,-5.020251274108887,-6.982583045959473,-5.890954494476318,-3.476339101791382,-3.9237582683563232,-5.955692291259766,-4.38620662689209,-5.885634422302246,-7.090954780578613,-4.403400421142578,-4.962924480438232,-3.61368727684021,-8.390103340148926,-0.5611705780029297,-1.3342543840408325,-3.2856619358062744,-8.025403022766113,-9.29414176940918, ...

# %%
import plotly.express as px
from kaleido.scopes.plotly import PlotlyScope

embedding = adata.obsm['emb_pca']
mclust_labels = adata.obs["mclust"]

fig = px.scatter_3d(
    embedding,
    x=0,
    y=1,
    z=2,
    color=mclust_labels,
    title="3D Embedding with GENESPAT",
)

fig.write_html("3d_embedding.html")

fig.show()

scope = PlotlyScope()
img_bytes = scope.transform(fig, format="png", width=800, height=600, scale=2.0)
with open("3d_embedding.png", "wb") as f:
    f.write(img_bytes)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3ff051cc-314d-4e85-8adf-69bae4129a16" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ff051cc-314d-4e85-8adf-69bae4129a16")) {                    Plotly.newPlot(                        "3ff051cc-314d-4e85-8adf-69bae4129a16",                        [{"hovertemplate":"color=3\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"3","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"3","scene":"scene","showlegend":true,"x":[-4.96307897567749,-2.7418875694274902,-6.990638256072998,-6.108727931976318,-4.996501445770264,-3.7364749908447266,-5.523031234741211,-2.4084980487823486,-0.4380231201648712,-2.9132490158081055,-5.7701544761657715,-5.305004119873047,-7.600839614868164,-4.539161682128906,-8.948527336120605,-5.383172988891602,-3.552248477935791,-5.899576663970947,-3.0388426780700684,-3.7135016918182373,-6.842713356018066,-1.1551364660263062,5.2287797927856445,-6.6882524490356445,-0.4380662143230438,-7.431769371032715,-7.249168395996094,-5.36077880859375,-0.32442009449005127,-5.970727920532227,-5.800305366516113,-10.304497718811035,-1.099179744720459,-3.9580729007720947,-2.6244618892669678,-3.330876111984253,-2.910287857055664,-2.0475430488586426,-5.8668599128723145,-5.135390758514404,-3.1864943504333496,-2.9256086349487305,-8.152486801147461,-8.283099174499512,-6.443780422210693,-8.013832092285156,1.86614191532135,-6.885595798492432,-6.932252883911133,-1.6109338998794556,-7.930479049682617,1.9232892990112305,-7.492140293121338,-5.505044937133789,-0.5497979521751404,-9.353102684020996,-8.078034400939941,-6.598191738128662,-4.183879852294922,-8.024128913879395,-2.6334023475646973,-7.592875957489014,-8.021029472351074,-8.28459644317627,-7.732846736907959,-3.4874038696289062,-7.357230186462402,-5.73326301574707,-1.514732003211975,-7.457437038421631,-1.6735916137695312,-8.601502418518066,-6.2273783683776855,-6.322330474853516,-8.152761459350586,-0.7163372039794922,-6.7755537033081055,-5.966793537139893,-3.0975749492645264,-6.685412883758545,-7.848785877227783,-1.7726225852966309,-4.002461910247803,-4.21584415435791,-10.527427673339844,-5.060801029205322,-2.114302635192871,-4.896928310394287,-8.747027397155762,-3.4787559509277344,-8.819662094116211,-3.6727075576782227,-4.844329833984375,-4.414717674255371,-6.472933769226074,-6.481365203857422,-6.7305989265441895,-3.9427483081817627,-6.5408406257629395,-5.1120429039001465,-2.675039291381836,-3.7038302421569824,-8.290801048278809,-0.2648458480834961,-2.964754343032837,-8.170180320739746,-8.0355806350708,-6.402848720550537,-8.408350944519043,-2.4924654960632324,-2.0497474670410156,-5.330253601074219,-3.433004140853882,-6.971902370452881,-4.2561821937561035,-4.0839128494262695,-4.471527099609375,-7.123473644256592,-7.602591514587402,-6.810490608215332,-2.041048765182495,-5.102437973022461,-1.942883014678955,-5.048992156982422,0.1770125925540924,-4.567780017852783,-5.930119037628174,-9.344797134399414,-4.776395320892334,-6.286082744598389,-4.1638407707214355,-10.311691284179688,-10.045578002929688,0.008486141450703144,-0.8743237257003784,-9.389480590820312,-1.9521983861923218,-5.638360023498535,-3.4137461185455322,-1.7966800928115845,-1.2153810262680054,-1.1594573259353638,-3.666318655014038,-8.079296112060547,-4.066215515136719,-8.079425811767578,-5.145116806030273,-6.020544528961182,0.06232244148850441,-5.275156497955322,-2.099938154220581,-4.916130542755127,-6.643413066864014,-7.924217224121094,-6.1775383949279785,-6.2416768074035645,-6.160669326782227,-1.5585297346115112,-1.1790812015533447,-4.788069248199463,-1.2784651517868042,0.3621830344200134,-0.67684406042099,-2.8543646335601807,-4.5883083 ...

# %%
ARI = metrics.adjusted_rand_score(adata.obs['mclust'], adata.obs['Ground_Truth'])
adata.uns['ARI'] = ARI
print('ARI:', ARI)
# Out:
# ARI: 0.5926091472129313

# %%
sc.pl.spatial(adata,
              img_key="hires",
              color=["Ground_Truth", "mclust"],
              title=["Ground_Truth", "ARI=%.4f"%ARI],
              show=True)
