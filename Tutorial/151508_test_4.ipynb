# %%
import anndata
import scanpy as sc
from sklearn import metrics
import matplotlib as mpl
from matplotlib import pyplot as plt
import numpy as np
import plotly.express as px

adata = anndata.read_h5ad(filename='Tutorial/all_adatas/151508_adata.h5ad')

# %%
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 4381 × 33538
#     obs: 'in_tissue', 'array_row', 'array_col', 'imagecol', 'imagerow', 'slices_path', 'Ground_Truth', 'mclust'
#     var: 'gene_ids', 'feature_types', 'genome', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'mean', 'std'
#     uns: 'ARI', 'Ground_Truth_colors', 'hvg', 'log1p', 'mclust_colors', 'neighbors', 'spatial'
#     obsm: 'adj', 'combined_feat', 'distance_matrix', 'emb', 'emb_pca', 'feat_a', 'graph_neigh', 'image_feat', 'label_CSL', 'spatial'
#     obsp: 'connectivities', 'distances'

# %%
sc.pl.highest_expr_genes(adata, n_top=20)

# %%
cell_index = 0
gene_expression = adata.X[cell_index]
expressed_gene_indices = gene_expression.nonzero()[1]
expressed_genes = adata.var_names[expressed_gene_indices]
print(expressed_genes)
# Out:
# Index(['HES4', 'B3GALT6', 'AURKAIP1', 'ATAD3A', 'MIB2', 'GNB1', 'PRKCZ',
#        'FAAP20', 'FAM213B', 'CHD5',
#        ...
#        'MT-CO1', 'MT-CO2', 'MT-ATP8', 'MT-ATP6', 'MT-CO3', 'MT-ND3', 'MT-ND4L',
#        'MT-ND4', 'MT-ND5', 'MT-CYB'],
#       dtype='object', length=1847)

# %%
with mpl.rc_context({'figure.figsize': [6, 7], 'axes.facecolor': 'black'}):
    sc.pl.spatial(adata,
                  color=[ "HES4","SDF4", "CPTP"],
                  img_key=None,
                  size=1,
                  vmin=0,
                  cmap='magma',
                  vmax='p99.0',
                  gene_symbols='SYMBOL'
                 )

# %%
gene_counts_sum = np.sum(adata.X, axis=0)
gene_with_most_counts = adata.var_names[np.argmax(gene_counts_sum)]
print("Gene with the most counts:", gene_with_most_counts)
# Out:
# Gene with the most counts: MT-CO1

# %%
sc.tl.umap(adata, n_components=2)
sc.pl.umap(adata)

# %%
sc.tl.diffmap(adata)

# %%
sc.pl.diffmap(adata, color='mclust')

# %%
sc.pl.diffmap(adata, color='Ground_Truth')

# %%
sc.tl.draw_graph(adata)
# Out:
# WARNING: Package 'fa2' is not installed, falling back to layout 'fr'.To use the faster and better ForceAtlas2 layout, install package 'fa2' (`pip install fa2`).

# %%
sc.pl.draw_graph(adata, color=['Ground_Truth', 'mclust'])

# %%
sc.pl.umap(adata, color=["HES4", "SDF4", "CPTP"])

# %%
plt.rcParams["figure.figsize"] = (4, 4)
sc.pl.umap(adata, color=["mclust"], wspace=0.4)

# %%
sc.pl.highly_variable_genes(adata)

# %%
sc.pp.pca(adata)

# %%
sc.pl.pca_variance_ratio(adata, log=True)

# %%
sc.tl.rank_genes_groups(adata, "mclust", method="t-test")

# %%
sc.pl.rank_genes_groups(adata, n_genes=10)

# %%
result = adata.uns["rank_genes_groups"]
groups = result["names"].dtype.names
top_features = {}
n_top_genes = 10
for group in groups:
    top_features[group] = result["names"][group][:n_top_genes]

for group, features in top_features.items():
    print(f"Cluster {group} top features:")
    for feature in features:
        print(feature)
    print()
# Out:
# Cluster 1 top features:
# MBP
# PLP1
# GFAP
# CRYAB
# CNP
# MOBP
# TF
# FTH1
# RPLP1
# CLDND1
#
# Cluster 2 top features:
# NRGN
# NEFL
# MAP1B
# LMO4
# YWHAH
# TUBA1B
# NEFM
# GAP43
# ENC1
# MT-ND3
#
# Cluster 3 top features:
# ENC1
# CAMK2N1
# HPCAL1
# OLFM1
# VSNL1
# GPM6A
# HOPX
# CALM1
# NRGN
# PPP3CA
#
# Cluster 4 top features:
# SCGB2A2
# TMSB10
# TUBA1B
# SNAP25
# MBP
# TUBB2A
# SCGB1D2
# SYT1
# STMN2
# MAP1B
#
# Cluster 5 top features:
# SCGB2A2
# MBP
# SCGB1D2
# S100A11
# PLP1
# KRT8
# FTH1
# AGR2
# IGKC
# KRT18
#
# Cluster 6 top features:
# CST3
# GFAP
# MT3
# SNORC
# AQP4
# S100B
# CLU
# AGT
# PTGDS
# CXCL14
#
# Cluster 7 top features:
# CST3
# FABP4
# SAA1
# GFAP
# MT3
# CLU
# MT-ND5
# VIM
# S100B
# SNORC

# %%
embedding = adata.obsm['emb_pca']
mclust_labels = adata.obs["mclust"]

fig = px.scatter_3d(
    embedding,
    x=0,
    y=1,
    z=2,
    color=mclust_labels,
    title="3D Embedding with GENESPAT",
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="86ce9df5-ac55-42a3-b18c-da088576139a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86ce9df5-ac55-42a3-b18c-da088576139a")) {                    Plotly.newPlot(                        "86ce9df5-ac55-42a3-b18c-da088576139a",                        [{"hovertemplate":"color=2\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"2","scene":"scene","showlegend":true,"x":[-4.178697109222412,-3.7815229892730713,-2.3719561100006104,-6.710080146789551,0.6313953399658203,-6.426126956939697,-4.325706958770752,-5.903430938720703,-3.6031312942504883,-7.381264686584473,-1.8346396684646606,-5.713761806488037,-4.769165992736816,2.433847427368164,-4.324100971221924,-3.2230944633483887,-3.6554501056671143,-0.6913665533065796,-0.6101819276809692,-2.0346007347106934,-2.326328754425049,1.1796618700027466,-4.303865909576416,-4.026726245880127,-3.693007230758667,-2.1076881885528564,-2.910076856613159,-1.436285376548767,-3.836055278778076,-2.410024642944336,-4.275918960571289,-3.9560916423797607,-2.159153461456299,-0.7345185875892639,-3.7856955528259277,-1.2648106813430786,-3.6769983768463135,-3.852269411087036,-2.7556397914886475,-1.5293614864349365,-4.8560261726379395,-6.083624839782715,-5.019897937774658,-1.6320661306381226,-3.643791913986206,-2.2246408462524414,-4.226494312286377,-2.28359055519104,-5.60577392578125,-2.216999053955078,-1.3077259063720703,-5.8390607833862305,-2.7875237464904785,-5.906488418579102,-3.1425375938415527,-6.8675079345703125,-6.203498840332031,-3.3840386867523193,4.765629768371582,-4.147830486297607,-9.484413146972656,-3.1599812507629395,-3.1253416538238525,-5.352027893066406,-1.6337409019470215,-2.82043194770813,-3.369114875793457,-4.179972171783447,0.38536015152931213,4.9399518966674805,-5.74406623840332,-3.4286515712738037,-5.5826826095581055,4.838635444641113,-5.275712966918945,-9.01263427734375,-2.7625045776367188,-4.185367584228516,-0.6329494118690491,-2.3575730323791504,-4.0539703369140625,-3.5890984535217285,-3.642406463623047,-4.8853044509887695,-3.99430775642395,-5.863524436950684,-1.416456937789917,-2.8097152709960938,1.9439877271652222,-3.297760248184204,3.0476632118225098,-2.674138307571411,-2.319230794906616,